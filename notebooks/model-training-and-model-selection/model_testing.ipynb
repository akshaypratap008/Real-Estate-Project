# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline

# %%
with open(r'C:\Users\apaks\Desktop\Real Estate Project\artifacts\model.pkl', 'rb') as f: 
    model = pickle.load(f)

with open(r'C:\Users\apaks\Desktop\Real Estate Project\artifacts\preprocessor.pkl', 'rb') as f: 
    preprocessor = pickle.load(f)

# %%
X_test = pd.DataFrame([{
    'property_type': 'house',
    'sector': 'sector 43',
    'bedRoom': 4,
    'bathroom': 4,
    'balcony': '2',
    'agePossession': 'under construction',
    'built_up_area': np.log1p(2430.06),
    'servant room': 1,
    'store room': 1,
    'furnishing_type': 'furnished',
    'luxury_category': 'luxury',
    'floor_category': 'medium-rise'
}])

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', model)
])

# %%
y_pred = pipeline.predict(X_test)
print(y_pred)
# Out:
# [2.03843072]

# %%
print(np.expm1(y_pred))
# Out:
# [6.67854996]

# %%
test_df = pd.read_csv(r"C:\Users\apaks\Desktop\Real Estate Project\artifacts\test.csv")

# %%
test_df
# Out:
#     property_type      sector  price  bedRoom  bathroom balcony  \
# 0           house  sector 109   6.80        4         5       3
# 1            flat   sector 56   1.38        3         3       3
# 2            flat   sector 86   0.90        3         3       2
# 3           house   sector 47   0.49        2         2       1
# 4            flat   sector 49   3.00        4         4       3
# ..            ...         ...    ...      ...       ...     ...
# 695          flat   sector 22   4.30        3         4      3+
# 696          flat   sector 91   0.95        2         2       2
# 697         house   sector 43   5.25        4         4       2
# 698          flat   sector 47   0.40        2         2       2
# 699          flat  sector 109   2.20        3         4       3
#
#       agePossession  built_up_area  servant room  store room furnishing_type  \
# 0    relatively new        5400.00             1           0     unfurnished
# 1    relatively old        1910.00             0           0   semifurnished
# 2               new        1690.00             0           0     unfurnished
# 3               new        1150.00             0           0     unfurnished
# 4    relatively old        2200.00             1           0   semifurnished
# ..              ...            ...           ...         ...             ...
# 695  relatively new        2600.00             1           0       furnished
# 696  relatively new        1191.00             0           0     unfurnished
# 697             old        1934.98             1           0   semifurnished
# 698             new         900.00             0           0     unfurnished
# 699  relatively new        1860.00             1           0     unfurnished
#
#     luxury_category floor_category
# 0            budget       low-rise
# 1            luxury    medium-rise
# 2            budget    medium-rise
# 3            budget       low-rise
# 4            luxury    medium-rise
# ..              ...            ...
# 695          luxury    medium-rise
# 696     semi-luxury    medium-rise
# 697     semi-luxury       low-rise
# 698     semi-luxury       low-rise
# 699          luxury      high-rise
#
# [700 rows x 13 columns]

# %%
X = test_df.drop(columns = ['price'])
y = test_df['price']

# %%
X
# Out:
#     property_type      sector  bedRoom  bathroom balcony   agePossession  \
# 0           house  sector 109        4         5       3  relatively new
# 1            flat   sector 56        3         3       3  relatively old
# 2            flat   sector 86        3         3       2             new
# 3           house   sector 47        2         2       1             new
# 4            flat   sector 49        4         4       3  relatively old
# ..            ...         ...      ...       ...     ...             ...
# 695          flat   sector 22        3         4      3+  relatively new
# 696          flat   sector 91        2         2       2  relatively new
# 697         house   sector 43        4         4       2             old
# 698          flat   sector 47        2         2       2             new
# 699          flat  sector 109        3         4       3  relatively new
#
#      built_up_area  servant room  store room furnishing_type luxury_category  \
# 0          5400.00             1           0     unfurnished          budget
# 1          1910.00             0           0   semifurnished          luxury
# 2          1690.00             0           0     unfurnished          budget
# 3          1150.00             0           0     unfurnished          budget
# 4          2200.00             1           0   semifurnished          luxury
# ..             ...           ...         ...             ...             ...
# 695        2600.00             1           0       furnished          luxury
# 696        1191.00             0           0     unfurnished     semi-luxury
# 697        1934.98             1           0   semifurnished     semi-luxury
# 698         900.00             0           0     unfurnished     semi-luxury
# 699        1860.00             1           0     unfurnished          luxury
#
#     floor_category
# 0         low-rise
# 1      medium-rise
# 2      medium-rise
# 3         low-rise
# 4      medium-rise
# ..             ...
# 695    medium-rise
# 696    medium-rise
# 697       low-rise
# 698       low-rise
# 699      high-rise
#
# [700 rows x 12 columns]

# %%
y
# Out:
# 0      6.80
# 1      1.38
# 2      0.90
# 3      0.49
# 4      3.00
#        ...
# 695    4.30
# 696    0.95
# 697    5.25
# 698    0.40
# 699    2.20
# Name: price, Length: 700, dtype: float64

# %%
y.shape
# Out:
# (700,)

# %%
X['built_up_area'] = np.log1p(X['built_up_area'])

# %%
y_pred = np.expm1(pipeline.predict(X))

# %%
y_pred.shape
# Out:
# (700,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.scatter(y, y_pred, alpha=0.5)
plt.plot([y.min(), y.max()],
         [y.min(), y.max()],
         color='red')  # perfect prediction line
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error
from sklearn.model_selection import cross_val_score, KFold

r2 = r2_score(y, y_pred)
mae = mean_absolute_error(y, y_pred)
rmse = root_mean_squared_error(y, y_pred)

print('r2: ', r2)
print('mae: ', mae)
print('rmse: ', rmse)
kfold = KFold(n_splits = 10, shuffle = True, random_state = 42)
scores = cross_val_score(pipeline, X, y, cv = kfold, scoring = 'r2', n_jobs = -1, verbose = 0)

print('mean r2 score: ', scores.mean())
print('std deviation: ', scores.std())
# Out:
# r2:  0.8217275566672724
# mae:  0.48142559682649766
# rmse:  1.2320377174204593
# mean r2 score:  0.7424471803221697
# std deviation:  0.1878641591841589

# %%
residuals = y - y_pred

plt.scatter(y, residuals)
plt.axhline(0, color='red')

# %%
y.mean()
# Out:
# np.float64(2.519842857142857)
