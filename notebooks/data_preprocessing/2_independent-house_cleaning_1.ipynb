# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir(r'C:\Users\apaks\Desktop\Real Estate Project')

# %%
df = pd.read_csv(r'artifacts\data\raw-data\independent-house.csv')

# %%
df.head()
# Out:
#                                       property_name  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon
# 1  5 Bedroom House for sale in Sector 21A Faridabad
# 2  10 Bedroom House for sale in Sushant Lok Phase 1
# 3    21 Bedroom House for sale in Sector 54 Gurgaon
# 4  12 Bedroom House for sale in Sushant Lok Phase 1
#
#                                                 link           society  \
# 0  https://www.99acres.com/5-bhk-bedroom-independ...  Bptp Visionnaire
# 1  https://www.99acres.com/5-bhk-bedroom-independ...               NaN
# 2  https://www.99acres.com/10-bhk-bedroom-indepen...               NaN
# 3  https://www.99acres.com/21-bhk-bedroom-indepen...               NaN
# 4  https://www.99acres.com/12-bhk-bedroom-indepen...               NaN
#
#         price              rate                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# ...

# %%
df.isna().sum()
# Out:
# property_name        0
# link                 0
# society            624
# price              127
# rate                41
# area                 0
# areaWithType       108
# bedRoom            108
# bathroom           108
# balcony            108
# additionalRoom     506
# address             64
# noOfFloor          128
# facing             421
# agePossession      108
# nearbyLocations    182
# description         59
# furnishDetails     352
# features           421
# rating             188
# property_id         59
# dtype: int64

# %%
df.shape
# Out:
# (1095, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   str
#  1   link             1095 non-null   str
#  2   society          471 non-null    str
#  3   price            968 non-null    str
#  4   rate             1054 non-null   str
#  5   area             1095 non-null   str
#  6   areaWithType     987 non-null    str
#  7   bedRoom          987 non-null    str
#  8   bathroom         987 non-null    str
#  9   balcony          987 non-null    str
#  10  additionalRoom   589 non-null    str
#  11  address          1031 non-null   str
#  12  noOfFloor        967 non-null    str
#  13  facing           674 non-null    str
#  14  agePossession    987 non-null    str
#  15  nearbyLocations  913 non-null    str
#  16  description      1036 non-null   str
#  17  furnishDetails   743 non-null    str
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
# rows with missing property_id, most of the data is missing. Therefore drop them

df= df[~df['property_id'].isna()]

# %%
df.shape
# Out:
# (1036, 21)

# %%
# rename rate to price_per_sqft to match the floor file
df.rename(columns= {'rate': 'price_per_sqft'}, inplace = True)

# %%
# drop link and property_id column
df.drop(columns = ['link', 'property_id'], inplace = True)

# %%
# drop duplicates
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# property_name        0
# society            579
# price               60
# price_per_sqft      37
# area                 0
# areaWithType        41
# bedRoom             41
# bathroom            41
# balcony             41
# additionalRoom     437
# address              5
# noOfFloor           60
# facing             353
# agePossession       41
# nearbyLocations    123
# description          0
# furnishDetails     283
# features           353
# rating             128
# dtype: int64

# %% [markdown]
# ### Society Column

# %%
df['society'].isna().sum()
# Out:
# np.int64(579)

# %%
pd.set_option('display.max_rows', None)

# %%
df['society'].value_counts().sort_index()
# Out:
# society
# 4S Aradhya Homes                                      1
# ATS Tourmaline3.9 ★                                   1
# Adani Brahma Samsara4.2 ★                             1
# All Punjabi Welfare Association                       1
# Anamika Enclave                                       1
# Anand Garden, Sector-105                              1
# Anant Raj Estates                                     3
# Ansal                                                 1
# Ansal API Esencia3.7 ★                                2
# Ansal API Spanish Court                               1
# Ansal Celebrity Homes                                 1
# Ansal Esencia Sovereign Floors                        1
# Ansal Florence Super                                  1
# Ansal Heights3.2 ★                                    1
# Ansal Sushant Lok                                     1
# Ansal Sushant Lok 2                                   1
# Ansal Sushant Lok Plots4.1 ★                          4
# ...

# %%
df['society']=df['society'].replace('nul', 'independent')

# %%
import re

# remove rating from the name
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df['society'].value_counts().sort_index()
# Out:
# society
# 4s aradhya homes                                       1
# adani brahma samsara                                   1
# all punjabi welfare association                        1
# anamika enclave                                        1
# anand garden, sector-105                               1
# anant raj estates                                      3
# ansal                                                  1
# ansal api esencia                                      2
# ansal api spanish court                                1
# ansal celebrity homes                                  1
# ansal esencia sovereign floors                         1
# ansal florence super                                   1
# ansal heights                                          1
# ansal sushant lok                                      1
# ansal sushant lok 2                                    1
# ansal sushant lok plots                                4
# ...

# %%
df['society'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['society'] = df['society'].replace('nan', 'independent')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#         price    price_per_sqft                   area  \
# 0  5.25 Crore   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1   5.7 Crore  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2   2.1 Crore   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3     5 Crore   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4     3 Crore   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %% [markdown]
# ### Price column

# %%
df['price'].value_counts().sort_index()
# Out:
# price
# 1 Crore              8
# 1.04 Crore           1
# 1.05 Crore           2
# 1.07 Crore           1
# 1.1 Crore            9
# 1.15 Crore           6
# 1.16 Crore           3
# 1.18 Crore           1
# 1.2 Crore            7
# 1.25 Crore           5
# 1.27 Crore           1
# 1.3 Crore            7
# 1.34 Crore           1
# 1.35 Crore           7
# 1.39 Crore           1
# 1.4 Crore            4
# 1.44 Crore           1
# 1.45 Crore           6
# 1.5 Crore           11
# 1.52 Crore           1
# 1.55 Crore           3
# 1.6 Crore            8
# 1.64 Crore           1
# 1.65 Crore           4
# 1.7 Crore            9
# 1.72 Crore           1
# 1.75 Crore           2
# 1.8 Crore            5
# 1.83 Crore           1
# 1.85 Crore           3
# 1.87 Crore           1
# 1.9 Crore            3
# 1.95 Crore           3
# 10 Crore            10
# 10.3 Crore           1
# 10.45 Crore          2
# 10.5 Crore           6
# 10.55 Crore          2
# 10.56 Crore          1
# ...

# %%
# drop price on request
df = df[df['price'] != 'Price on Request']

# %%
df['price'] = df['price'].str.strip().str.lower()

# %%
# convert prices to crores and remove 'crore' and 'lac'

def treat_price(price):
    if type(price) == float:
        return price
    else:
        if price[1] == 'lac':
            return float(price[0]) * 0.01
        else:
            return float(price[0])

# %%
df['price'] = df['price'].str.strip().str.split(' ').apply(treat_price).round(2)

# %%
df['price'].isna().sum()
# Out:
# np.int64(60)

# %%
df.rename(columns = {'price': 'price_in_cr'}, inplace=True)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#    price_in_cr    price_per_sqft                   area  \
# 0         5.25   ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area
# 1         5.70  ₹ 105,751/sq.ft.   (50 sq.m.) Plot Area
# 2         2.10   ₹ 38,251/sq.ft.   (51 sq.m.) Plot Area
# 3         5.00   ₹ 43,066/sq.ft.  (108 sq.m.) Plot Area
# 4         3.00   ₹ 53,763/sq.ft.   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# ...

# %% [markdown]
# ### price_per_sqft column

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.strip().str.extract(r'([\d,]+)')

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.replace(',', '')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#    price_in_cr price_per_sqft                   area  \
# 0         5.25          20115  (242 sq.m.) Plot Area
# 1         5.70         105751   (50 sq.m.) Plot Area
# 2         2.10          38251   (51 sq.m.) Plot Area
# 3         5.00          43066  (108 sq.m.) Plot Area
# 4         3.00          53763   (52 sq.m.) Plot Area
#
#                   areaWithType      bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)   5 Bedrooms   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)   5 Bedrooms   4 Bathrooms   2 Balconies
# ...

# %% [markdown]
# ### bedroom, bathroom, balcony column

# %%
# bedroom
df['bedRoom'] = df['bedRoom'].str.strip().str.replace('Bedrooms', '').str.replace('Bedroom', '').str.strip().astype('Int64')
df = df[~df['bedRoom'].isnull()]

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#    price_in_cr price_per_sqft                   area  \
# 0         5.25          20115  (242 sq.m.) Plot Area
# 1         5.70         105751   (50 sq.m.) Plot Area
# 2         2.10          38251   (51 sq.m.) Plot Area
# 3         5.00          43066  (108 sq.m.) Plot Area
# 4         3.00          53763   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom      bathroom       balcony  \
# 0  Plot area 290(242.48 sq.m.)        5   4 Bathrooms  3+ Balconies
# 1   Plot area 539(50.07 sq.m.)        5   4 Bathrooms   2 Balconies
# ...

# %%
#bathroom

df['bathroom'] = df['bathroom'].str.strip().str.split(' ').str.get(0).astype('Int64')
df['bathroom'].isnull().sum()
# Out:
# np.int64(0)

# %%
# balcony
df['balcony'] = df['balcony'].str.replace('No', '0').str.strip().str.split(' ').str.get(0)

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#    price_in_cr price_per_sqft                   area  \
# 0         5.25          20115  (242 sq.m.) Plot Area
# 1         5.70         105751   (50 sq.m.) Plot Area
# 2         2.10          38251   (51 sq.m.) Plot Area
# 3         5.00          43066  (108 sq.m.) Plot Area
# 4         3.00          53763   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %% [markdown]
# ### additional room

# %%
df['additionalRoom'].value_counts().sort_index()
# Out:
# additionalRoom
# Others                                           58
# Pooja Room                                       38
# Pooja Room,Others                                11
# Pooja Room,Servant Room                          24
# Pooja Room,Servant Room,Others                    5
# Pooja Room,Servant Room,Store Room                7
# Pooja Room,Servant Room,Study Room,Store Room     4
# Pooja Room,Store Room                            11
# Pooja Room,Store Room,Servant Room                1
# Pooja Room,Store Room,Study Room,Servant Room     8
# Pooja Room,Study Room                            11
# Pooja Room,Study Room,Others                      4
# Pooja Room,Study Room,Servant Room               33
# Pooja Room,Study Room,Servant Room,Others        32
# Pooja Room,Study Room,Servant Room,Store Room    60
# Pooja Room,Study Room,Store Room                  3
# Pooja Room,Study Room,Store Room,Servant Room     2
# Servant Room                                     81
# ...

# %%
df['additionalRoom'] = df['additionalRoom'].fillna('not available').str.lower()

# %% [markdown]
# ### noOfFloor column

# %%
df['noOfFloor'].value_counts().sort_index()
# Out:
# noOfFloor
# 0 Floors       6
# 02 Floors      1
# 1 Floors     181
# 10 Floors      2
# 11 Floors      2
# 12 Floors      2
# 13 Floors      1
# 14 Floors      3
# 16 Floors      1
# 2 Floors     288
# 20 Floors      1
# 21 Floors      1
# 27 Floors      1
# 3 Floors     304
# 33 Floors      1
# 4 Floors     136
# 41 Floors      1
# 5 Floors       9
# 51 Floors      1
# 6 Floors       3
# Name: count, dtype: int64

# %%
df['noOfFloor'] = df['noOfFloor'].str.strip().str.split(' ').str.get(0).astype('Int64')

# %%
df['noOfFloor'].isnull().sum()
# Out:
# np.int64(19)

# %%
df[df['noOfFloor'].isnull()]
# Out:
#                                           property_name  \
# 23        4 Bedroom House for sale in Sector 48 Gurgaon
# 51              8 Bedroom House for sale in Palam Vihar
# 203             3 Bedroom House for sale in DLF Phase 3
# 252             3 Bedroom House for sale in Ashok Vihar
# 270    2 Bedroom House for sale in Laxman Vihar Phase 2
# 281   3 Bedroom House for sale in New Palam Vihar Ph...
# 374            4 Bedroom House for sale in Laxman Vihar
# 397     1 Bedroom House for sale in Sushant Lok Phase 1
# 417         2 Bedroom House for sale in Bhawani Enclave
# 560               2 Bedroom House for sale in Jacobpura
# 594             6 Bedroom House for sale in DLF Phase 2
# 666              3 Bedroom House for sale in New Colony
# 709      12 Bedroom House for sale in Sector 46 Gurgaon
# 832       4 Bedroom House for sale in Sector 86 Gurgaon
# 855       4 Bedroom House for sale in Sector 48 Gurgaon
# 862     4 Bedroom House for sale in Sushant Lok Phase 1
# ...

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#    price_in_cr price_per_sqft                   area  \
# 0         5.25          20115  (242 sq.m.) Plot Area
# 1         5.70         105751   (50 sq.m.) Plot Area
# 2         2.10          38251   (51 sq.m.) Plot Area
# 3         5.00          43066  (108 sq.m.) Plot Area
# 4         3.00          53763   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
df.rename(columns = {'noOfFloor': 'floorNum'}, inplace = True)

# %% [markdown]
# ### facing column

# %%
df['facing'].value_counts().sort_index()
# Out:
# facing
# East          178
# North         109
# North-East    158
# North-West     44
# South          34
# South-East     39
# South-West     24
# West           75
# Name: count, dtype: int64

# %%
df['facing']= df['facing'].fillna('NA')

# %%
df.head()
# Out:
#                                       property_name           society  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire
# 1  5 Bedroom House for sale in Sector 21A Faridabad       independent
# 2  10 Bedroom House for sale in Sushant Lok Phase 1       independent
# 3    21 Bedroom House for sale in Sector 54 Gurgaon       independent
# 4  12 Bedroom House for sale in Sushant Lok Phase 1       independent
#
#    price_in_cr price_per_sqft                   area  \
# 0         5.25          20115  (242 sq.m.) Plot Area
# 1         5.70         105751   (50 sq.m.) Plot Area
# 2         2.10          38251   (51 sq.m.) Plot Area
# 3         5.00          43066  (108 sq.m.) Plot Area
# 4         3.00          53763   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# ...

# %%
df.shape
# Out:
# (964, 19)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 964 entries, 0 to 1090
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    964 non-null    str
#  1   society          964 non-null    str
#  2   price_in_cr      945 non-null    float64
#  3   price_per_sqft   945 non-null    str
#  4   area             964 non-null    str
#  5   areaWithType     964 non-null    str
#  6   bedRoom          964 non-null    Int64
#  7   bathroom         964 non-null    Int64
#  8   balcony          964 non-null    object
#  9   additionalRoom   964 non-null    str
#  10  address          959 non-null    str
#  11  floorNum         945 non-null    Int64
#  12  facing           964 non-null    str
#  13  agePossession    964 non-null    str
#  14  nearbyLocations  848 non-null    str
#  15  description      964 non-null    str
#  16  furnishDetails   729 non-null    str
#  17  features         662 non-null    str
# ...

# %%
df.insert(loc = 1, column = 'property_type', value='house')

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price_in_cr price_per_sqft                   area  \
# 0  bptp visionnaire         5.25          20115  (242 sq.m.) Plot Area
# 1       independent         5.70         105751   (50 sq.m.) Plot Area
# 2       independent         2.10          38251   (51 sq.m.) Plot Area
# 3       independent         5.00          43066  (108 sq.m.) Plot Area
# 4       independent         3.00          53763   (52 sq.m.) Plot Area
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# ...

# %%
df.to_csv(r'artifacts\data\preprocessed-data\independent_house_cleaned_1.csv')
