# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir(r'C:\Users\apaks\Desktop\Real Estate Project')

# %%
flats = pd.read_csv(r'artifacts\data\preprocessed-data\flats_cleaned_1.csv')
house = pd.read_csv(r'artifacts\data\preprocessed-data\independent_house_cleaned_1.csv')

# %%
df = pd.concat([flats, house], ignore_index=True)

# %%
# suffling the data

df = df.sample(df.shape[0], ignore_index=True)

# %%
df.to_csv(r'artifacts\data\preprocessed-data\gurgaon_properties.csv')

# %%
# Out:
# area
# (10 sq.m.) Built-up Area     1
# (100 sq.m.) Built-up Area    3
# (100 sq.m.) Carpet Area      1
# (100 sq.m.) Plot Area        6
# (1003 sq.m.) Plot Area       1
#                             ..
# 994.98                       1
# 996.09                       1
# 997.06                       2
# 998.02                       1
# 998.17                       2
# Name: count, Length: 2632, dtype: int64
